# %%
from google.colab import userdata
import os

token = userdata.get('GITHUB_TOKEN')

# !git clone https://{token}@github.com/Nick542k/PyTorch_learning_log.git
# %cd PyTorch_learning_log

# !git config user.email "2024511012@student.annuniv.edu"

# !git config user.name "Nick542k"
# Out:
# Cloning into 'PyTorch_learning_log'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 9 (delta 0), reused 6 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (9/9), 41.38 KiB | 2.30 MiB/s, done.
# /content/PyTorch_learning_log

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive"
# Out:
# 'Colab Notebooks'	   'Google AI Studio'
#  Doc			    IMG-20260220-WA0013.jpg
# 'Document from Nithish J'   KoR
# 'foundry  and welding'	    panda-franka-emika-datasheet.pdf
# 'Getting started.pdf'	   'Untitled folder'

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks"
# Out:
# 01_pytorch_workflow.ipynb  git_cmd.ipynb  Tensors_practice.ipynb

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/"*.ipynb "/content/PyTorch_learning_log/"
# Out:
# cp: target '/content/PyTorch_learning_log/' is not a directory

# %%
# %cd /content/PyTorch_learning_log
# !ls
# Out:
# /content/PyTorch_learning_log
# 01_pytorch_workflow.ipynb  notes.md  README.md

# %%
# !git add .
# !git commit
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
# !git add .
# !git commit -m "Added existing notebooks to learning log"
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
